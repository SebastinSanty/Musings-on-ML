# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
X_data = 2 * np.random.randn(100,1)
y_data = 4 + 3*X_data + 2*np.random.randn(100,1)
plt.scatter(X_data, y_data)

# %%
data = np.c_[X_data, y_data]

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(data, test_size=0.2, random_state=42)

# %%
X_train, y_train = np.hsplit(train_set, 2)
plt.scatter(X_train, y_train)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)

X_test, y_test = np.hsplit(test_set, 2)
y_pred = lin_reg.predict(X_test)
plt.plot(X_test, y_pred, color="red")
plt.scatter(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-02134b3541b6> in <module>()
#       7 y_pred = lin_reg.predict(X_test)
#       8 plt.plot(X_test, y_pred, color="red")
# ----> 9 plt.plot(X_train, y_train, kind='scatter')
#
# ~/Desktop/CS/Stuffs/DeepL/handson/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# ~/Desktop/CS/Stuffs/DeepL/handson/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# ~/Desktop/CS/Stuffs/DeepL/handson/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# ~/Desktop/CS/Stuffs/DeepL/handson/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# ~/Desktop/CS/Stuffs/DeepL/handson/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     393         ncx, ncy = x.shape[1], y.shape[1]
#     394         for j in xrange(max(ncx, ncy)):
# --> 395             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     396             ret.append(seg)
#     397         return ret
#
# ~/Desktop/CS/Stuffs/DeepL/handson/lib/python3.6/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     300         default_dict = self._getdefaults(None, kw)
#     301         self._setdefaults(default_dict, kw)
# --> 302         seg = mlines.Line2D(x, y, **kw)
#     303         return seg
#     304
#
# ~/Desktop/CS/Stuffs/DeepL/handson/lib/python3.6/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     429         # update kwargs before updating data to give the caller a
#     430         # chance to init axes (and hence unit support)
# --> 431         self.update(kwargs)
#     432         self.pickradius = pickradius
#     433         self.ind_offset = 0
#
# ~/Desktop/CS/Stuffs/DeepL/handson/lib/python3.6/site-packages/matplotlib/artist.py in update(self, props)
#     883         try:
#     884             ret = [_update_property(self, k, v)
# --> 885                    for k, v in props.items()]
#     886         finally:
#     887             self.eventson = store
#
# ~/Desktop/CS/Stuffs/DeepL/handson/lib/python3.6/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     883         try:
#     884             ret = [_update_property(self, k, v)
# --> 885                    for k, v in props.items()]
#     886         finally:
#     887             self.eventson = store
#
# ~/Desktop/CS/Stuffs/DeepL/handson/lib/python3.6/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     876                 func = getattr(self, 'set_' + k, None)
#     877                 if func is None or not six.callable(func):
# --> 878                     raise AttributeError('Unknown property %s' % k)
#     879                 return func(v)
#     880
#
# AttributeError: Unknown property kind

# %%
from sklearn.metrics import mean_squared_error

lin_mse = mean_squared_error(y_test, y_pred)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 2.1377528426529806

# %%
from scipy.stats import linregress
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d81b7a10e45d> in <module>()
#       1 from scipy.stats import linregress
#       2
# ----> 3 slope, intercept, rvalue, pvalue = linregress(X_test, y_pred)
#
# ~/Desktop/CS/Stuffs/DeepL/handson/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py in linregress(x, y)
#      90
#      91     # average sum of squares:
# ---> 92     ssxm, ssxym, ssyxm, ssym = np.cov(x, y, bias=1).flat
#      93     r_num = ssxym
#      94     r_den = np.sqrt(ssxm * ssym)
#
# ValueError: too many values to unpack (expected 4)
